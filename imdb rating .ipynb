# %% [markdown]
# import dependencies

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import re

# %%
data=pd.read_csv(r"C:\Users\Jayashri\Downloads\imdb_top_1000.csv")

# %% [markdown]
# display top 10 rows

# %%
data.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %% [markdown]
# last 10 rows

# %%
data.tail(10)
# Out:
#                                            Poster_Link  \
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 990            Giù la testa          1971          PG  157 min
# 991          Kelly's Heroes          1970          GP  144 min
# 992         The Jungle Book          1967           U   78 min
# 993                  Blowup          1966           A  111 min
# ...

# %% [markdown]
# no of rows and coloumns

# %%
data.shape
# Out:
# (1000, 16)

# %%
print("number of rows",data.shape[0])
print("number of coloumns",data.shape[1])
# Out:
# number of rows 1000
# number of coloumns 16

# %% [markdown]
# info about our data

# %%
data.info
# Out:
# <bound method DataFrame.info of                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# missing values in dataset

# %%
print('any missing value?',data.isnull().values.any())
# Out:
# any missing value? True

# %%
data.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing = data.isnull().sum() * 100/ len(data)
per_missing
# Out:
# Poster_Link       0.0
# Series_Title      0.0
# Released_Year     0.0
# Certificate      10.1
# Runtime           0.0
# Genre             0.0
# IMDB_Rating       0.0
# Overview          0.0
# Meta_score       15.7
# Director          0.0
# Star1             0.0
# Star2             0.0
# Star3             0.0
# Star4             0.0
# No_of_Votes       0.0
# Gross            16.9
# dtype: float64

# %% [markdown]
# drop all missing values

# %%
data.dropna(axis=0)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# check for duplicate data

# %%
dup_data= data.duplicated().any()

# %%
print('are there ny duplicate data?',dup_data)
# Out:
# are there ny duplicate data? False

# %% [markdown]
# overall statistics

# %%
data.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
data.describe(include='all')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...     Drishyam
# freq                                                    1            2
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# ...

# %% [markdown]
# display title of movie having runtime >=180 mins

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
remove='min'
data['Runtime']=data['Runtime'].str.replace(remove,'')
print(data)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate Runtime  \
# 0    The Shawshank Redemption          1994           A    142
# 1               The Godfather          1972           A    175
# 2             The Dark Knight          2008          UA    152
# ...

# %%
data['Runtime']
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#        ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime, Length: 1000, dtype: object

# %%
data[data['Runtime'] >= 180]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 data[data['Runtime'] >= 180]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# ...

# %% [markdown]
# highest avg voting

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
data.groupby('Released_Year')['No_of_Votes'].mean()
# Out:
# Released_Year
# 1920     57428.000000
# 1921    113314.000000
# 1922     88794.000000
# 1924     41985.000000
# 1925     77053.500000
#             ...
# 2017    258636.136364
# 2018    219519.157895
# 2019    260155.478261
# 2020     84127.000000
# PG      269197.000000
# Name: No_of_Votes, Length: 100, dtype: float64

# %%
data.groupby('Released_Year')['No_of_Votes'].mean().sort_values(ascending=False)
# Out:
# Released_Year
# 1994    666532.153846
# 1977    556087.333333
# 1999    536961.058824
# 2008    444044.904762
# 2010    431661.173913
#             ...
# 1928     38940.500000
# 1947     37204.500000
# 1945     34575.000000
# 1937     33829.000000
# 1932     33714.500000
# Name: No_of_Votes, Length: 100, dtype: float64

# %%
sb.barplot(x='Released_Year', y='No_of_Votes',data=data)
plt.title('votes by year')
plt.show()

# %% [markdown]
# avg rating for each director

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
data.groupby('Director')['IMDB_Rating'].mean()
# Out:
# Director
# Aamir Khan             8.40
# Aaron Sorkin           7.80
# Abdellatif Kechiche    7.70
# Abhishek Chaubey       7.80
# Abhishek Kapoor        7.70
#                        ...
# Zack Snyder            7.60
# Zaza Urushadze         8.20
# Zoya Akhtar            8.05
# Çagan Irmak            8.30
# Ömer Faruk Sorak       8.00
# Name: IMDB_Rating, Length: 548, dtype: float64

# %%
data.groupby('Director')['IMDB_Rating'].mean().sort_values()
# Out:
# Director
# Todd Haynes         7.60
# David Zucker        7.60
# David Mackenzie     7.60
# David Cronenberg    7.60
# David Ayer          7.60
#                     ...
# Roberto Benigni     8.60
# George Lucas        8.60
# Lana Wachowski      8.70
# Irvin Kershner      8.70
# Frank Darabont      8.95
# Name: IMDB_Rating, Length: 548, dtype: float64

# %% [markdown]
# display top 10 lengthy movies

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
data.nlargest(10,'Runtime')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 data.nlargest(10,'Runtime')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7338, in DataFrame.nlargest(self, n, columns, keep)
#    7233 def nlargest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#    7234     """
#    7235     Return the first `n` rows ordered by `columns` in descending order.
#    7236
#    (...)
#    7336     Brunei      434000    12128      BN
#    7337     """
# -> 7338     return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1277, in SelectN.nlargest(self)
#    1275 @final
#    1276 def nlargest(self):
# -> 1277     return self.compute("nlargest")
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 data['Runtime'] = data['Runtime'].str.extract('(\d+)').astype(int)
#       3 # Use nlargest() to find the largest values
#       4 n = 3  # Number of largest values to retrieve
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
# ...

# %% [markdown]
# no of movies acc to year

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
data['Released_Year'].value_counts()
# Out:
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: Released_Year, Length: 100, dtype: int64

# %%
sb.countplot(x='Released_Year',data=data)
# Out:
# <Axes: xlabel='Released_Year', ylabel='count'>

# %% [markdown]
# most popular movie highest rated

# %%
top10_len=data.nlargest(10,'IMDB_Rating')[['Series_Title','IMDB_Rating','Director']].set_index('Series_Title')

# %%
top10_len
# Out:
#                                                IMDB_Rating  \
# Series_Title
# The Shawshank Redemption                               9.3
# The Godfather                                          9.2
# The Dark Knight                                        9.0
# The Godfather: Part II                                 9.0
# 12 Angry Men                                           9.0
# The Lord of the Rings: The Return of the King          8.9
# Pulp Fiction                                           8.9
# Schindler's List                                       8.9
# Inception                                              8.8
# Fight Club                                             8.8
#
#                                                            Director
# Series_Title
# The Shawshank Redemption                             Frank Darabont
# The Godfather                                  Francis Ford Coppola
# The Dark Knight                                   Christopher Nolan
# ...

# %%
sb.barplot(x='IMDB_Rating' , y=top10_len.index,data=top10_len,hue='Director',dodge=False)
plt.legend(bbox_to_anchor=(1.05,1),loc=2)

# %% [markdown]
# avg rating movie year wise

# %%
data.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
data.groupby('Released_Year')['IMDB_Rating'].mean().sort_values()
# Out:
# Released_Year
# PG      7.600000
# 1935    7.766667
# 1943    7.800000
# 1933    7.800000
# 1956    7.820000
#           ...
# 1942    8.233333
# 1994    8.238462
# 1957    8.277778
# 1921    8.300000
# 1936    8.500000
# Name: IMDB_Rating, Length: 100, dtype: float64

# %% [markdown]
# classify movies based on rating

# %%
def rating(rating):
    if rating>=7.0:
        return "Excellent"
    elif rating>=6.0:
        return "Good"
    else:
        return "Average"

# %%
data['rating_cat']= data['IMDB_Rating'].apply(rating)

# %%
data.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %% [markdown]
# count no of action movie

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
len(data[data['Genre'].str.contains('Action',case=False)])
# Out:
# 189

# %% [markdown]
# unique values from genre

# %%
data['Genre']
# Out:
# 0                         Drama
# 1                  Crime, Drama
# 2          Action, Crime, Drama
# 3                  Crime, Drama
# 4                  Crime, Drama
#                  ...
# 995      Comedy, Drama, Romance
# 996              Drama, Western
# 997         Drama, Romance, War
# 998                  Drama, War
# 999    Crime, Mystery, Thriller
# Name: Genre, Length: 1000, dtype: object

# %%
list=[]
for value in data['Genre']:
     list.append(value.split(','))

# %%
list
# Out:
# [['Drama'],
#  ['Crime', ' Drama'],
#  ['Action', ' Crime', ' Drama'],
#  ['Crime', ' Drama'],
#  ['Crime', ' Drama'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Crime', ' Drama'],
#  ['Biography', ' Drama', ' History'],
#  ['Action', ' Adventure', ' Sci-Fi'],
#  ['Drama'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Drama', ' Romance'],
#  ['Western'],
#  ['Action', ' Adventure', ' Drama'],
#  ['Action', ' Sci-Fi'],
#  ['Biography', ' Crime', ' Drama'],
#  ['Action', ' Adventure', ' Fantasy'],
#  ['Drama'],
#  ['Biography', ' Drama', ' History'],
#  ['Comedy', ' Drama', ' Thriller'],
#  ['Drama'],
#  ['Adventure', ' Drama', ' Sci-Fi'],
#  ['Crime', ' Drama'],
#  ['Animation', ' Adventure', ' Family'],
#  ['Drama', ' War'],
#  ['Crime', ' Drama', ' Fantasy'],
#  ['Comedy', ' Drama', ' Romance'],
#  ['Crime', ' Drama', ' Mystery'],
#  ['Crime', ' Drama', ' Thriller'],
#  ['Action', ' Adventure', ' Fantasy'],
#  ['Action', ' Drama', ' Mystery'],
#  ['Action', ' Adventure', ' Drama'],
# ...

# %%
one=[]
for item in list:
    for item1 in item:
        one.append(item1)

# %%
one
# Out:
# ['Drama',
#  'Crime',
#  ' Drama',
#  'Action',
#  ' Crime',
#  ' Drama',
#  'Crime',
#  ' Drama',
#  'Crime',
#  ' Drama',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Crime',
#  ' Drama',
#  'Biography',
#  ' Drama',
#  ' History',
#  'Action',
#  ' Adventure',
#  ' Sci-Fi',
#  'Drama',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Drama',
#  ' Romance',
#  'Western',
#  'Action',
#  ' Adventure',
#  ' Drama',
#  'Action',
#  ' Sci-Fi',
#  'Biography',
#  ' Crime',
#  ' Drama',
#  'Action',
#  ' Adventure',
#  ' Fantasy',
#  'Drama',
#  'Biography',
#  ' Drama',
#  ' History',
#  'Comedy',
#  ' Drama',
#  ' Thriller',
#  'Drama',
#  'Adventure',
#  ' Drama',
#  ' Sci-Fi',
#  'Crime',
#  ' Drama',
#  'Animation',
#  ' Adventure',
#  ' Family',
#  'Drama',
#  ' War',
#  'Crime',
#  ' Drama',
#  ' Fantasy',
#  'Comedy',
#  ' Drama',
#  ' Romance',
#  'Crime',
#  ' Drama',
#  ' Mystery',
#  'Crime',
#  ' Drama',
#  ' Thriller',
#  'Action',
#  ' Adventure',
#  ' Fantasy',
# ...

# %%
ulist=[]
for item in one:
    if item not in ulist:
        ulist.append(item)

# %%
ulist
# Out:
# ['Drama',
#  'Crime',
#  ' Drama',
#  'Action',
#  ' Crime',
#  ' Adventure',
#  'Biography',
#  ' History',
#  ' Sci-Fi',
#  ' Romance',
#  'Western',
#  ' Fantasy',
#  'Comedy',
#  ' Thriller',
#  'Adventure',
#  'Animation',
#  ' Family',
#  ' War',
#  ' Mystery',
#  ' Music',
#  ' Comedy',
#  'Horror',
#  ' Biography',
#  ' Action',
#  ' Western',
#  'Mystery',
#  ' Horror',
#  ' Musical',
#  ' Film-Noir',
#  ' Sport',
#  'Film-Noir',
#  'Fantasy',
#  'Family',
#  'Thriller']

# %%
len(ulist)
# Out:
# 34

# %% [markdown]
# films of each genre

# %%
one=[]
for item in list:
    for item1 in item:
        one.append(item1)

# %%
from collections import Counter

# %%
Counter(one)
# Out:
# Counter({'Drama': 289,
#          'Crime': 107,
#          ' Drama': 435,
#          'Action': 172,
#          ' Crime': 102,
#          ' Adventure': 124,
#          'Biography': 88,
#          ' History': 56,
#          ' Sci-Fi': 67,
#          ' Romance': 125,
#          'Western': 4,
#          ' Fantasy': 64,
#          'Comedy': 155,
#          ' Thriller': 136,
#          'Adventure': 72,
#          'Animation': 82,
#          ' Family': 54,
#          ' War': 51,
#          ' Mystery': 87,
#          ' Music': 35,
#          ' Comedy': 78,
#          'Horror': 11,
#          ' Biography': 21,
#          ' Action': 17,
#          ' Western': 16,
#          'Mystery': 12,
#          ' Horror': 21,
#          ' Musical': 17,
#          ' Film-Noir': 16,
#          ' Sport': 19,
#          'Film-Noir': 3,
#          'Fantasy': 2,
#          'Family': 2,
#          'Thriller': 1})
